# %% [markdown]
# <a href="https://colab.research.google.com/github/yonseimath/data-science-2022-biginner/blob/feature%2Fjeahyuk/jeahyuk/6_3_PCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 주성분 분석

# %% [markdown]
# <table align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/rickiepark/hg-mldl/blob/master/6-3.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />구글 코랩에서 실행하기</a>
#   </td>
# </table>

# %% [markdown]
# ## PCA 클래스

# %%
# !wget https://bit.ly/fruits_300_data -O fruits_300.npy
# Out:
# --2022-05-22 05:12:34--  https://bit.ly/fruits_300_data
# Resolving bit.ly (bit.ly)... 67.199.248.10, 67.199.248.11
# Connecting to bit.ly (bit.ly)|67.199.248.10|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/rickiepark/hg-mldl/raw/master/fruits_300.npy [following]
# --2022-05-22 05:12:34--  https://github.com/rickiepark/hg-mldl/raw/master/fruits_300.npy
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/rickiepark/hg-mldl/master/fruits_300.npy [following]
# --2022-05-22 05:12:34--  https://raw.githubusercontent.com/rickiepark/hg-mldl/master/fruits_300.npy
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# ...

# %%
import numpy as np

fruits = np.load('fruits_300.npy')
fruits_2d = fruits.reshape(-1, 100*100)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=50)
pca.fit(fruits_2d)
# Out:
# PCA(n_components=50)

# %%
print(pca.components_.shape)
# Out:
# (50, 10000)

# %%
import matplotlib.pyplot as plt

def draw_fruits(arr, ratio=1):
    n = len(arr)    # n은 샘플 개수입니다
    # 한 줄에 10개씩 이미지를 그립니다. 샘플 개수를 10으로 나누어 전체 행 개수를 계산합니다. 
    rows = int(np.ceil(n/10))
    # 행이 1개 이면 열 개수는 샘플 개수입니다. 그렇지 않으면 10개입니다.
    cols = n if rows < 2 else 10
    fig, axs = plt.subplots(rows, cols, 
                            figsize=(cols*ratio, rows*ratio), squeeze=False)
    for i in range(rows):
        for j in range(cols):
            if i*10 + j < n:    # n 개까지만 그립니다.
                axs[i, j].imshow(arr[i*10 + j], cmap='gray_r')
            axs[i, j].axis('off')
    plt.show()

# %%
draw_fruits(pca.components_.reshape(-1, 100, 100))

# %%
print(fruits_2d.shape)
# Out:
# (300, 10000)

# %%
fruits_pca = pca.transform(fruits_2d)

# %%
print(fruits_pca.shape)
# Out:
# (300, 50)

# %% [markdown]
# ## 원본 데이터 재구성

# %%
fruits_inverse = pca.inverse_transform(fruits_pca)
print(fruits_inverse.shape)
# Out:
# (300, 10000)

# %%
fruits_reconstruct = fruits_inverse.reshape(-1, 100, 100)

# %%
for start in [0, 100, 200]:
    draw_fruits(fruits_reconstruct[start:start+100])
    print("\n")

# %% [markdown]
# ## 설명된 분산

# %%
print(np.sum(pca.explained_variance_ratio_))
# Out:
# 0.921558287891158

# %%
plt.plot(pca.explained_variance_ratio_)

# %% [markdown]
# ## 다른 알고리즘과 함께 사용하기

# %% [markdown]
# ### 분류기 LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()

# %%
target = np.array([0] * 100 + [1] * 100 + [2] * 100)

# %%
from sklearn.model_selection import cross_validate

scores = cross_validate(lr, fruits_2d, target)
print(np.mean(scores['test_score']))
print(np.mean(scores['fit_time']))
# Out:
# 0.9966666666666667
# 2.1341151714324953

# %%
scores = cross_validate(lr, fruits_pca, target)
print(np.mean(scores['test_score']))
print(np.mean(scores['fit_time']))
# Out:
# 1.0
# 0.0394538402557373

# %%
pca = PCA(n_components=0.5)
pca.fit(fruits_2d)
# Out:
# PCA(n_components=0.5)

# %%
print(pca.n_components_)
# Out:
# 2

# %%
fruits_pca = pca.transform(fruits_2d)
print(fruits_pca.shape)
# Out:
# (300, 2)

# %%
scores = cross_validate(lr, fruits_pca, target)
print(np.mean(scores['test_score']))
print(np.mean(scores['fit_time']))
# Out:
# 0.9933333333333334
# 0.04242515563964844
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# ## n_components(설명된 분산) 바꿔가면서 값 확인해보기

# %%
pca1 = PCA(n_components=0.6)
pca1.fit(fruits_2d)

print(pca1.n_components_)
# Out:
# 4

# %%
fruits_pca1 = pca1.transform(fruits_2d)
print(fruits_pca1.shape)
# Out:
# (300, 4)

# %%
scores = cross_validate(lr, fruits_pca1, target)
print(np.mean(scores['test_score']))
print(np.mean(scores['fit_time']))
# Out:
# 0.9933333333333334
# 0.02725358009338379

# %% [markdown]
# ### 군집 KMeans

# %%
from sklearn.cluster import KMeans

km = KMeans(n_clusters=3, random_state=42)
km.fit(fruits_pca)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
print(np.unique(km.labels_, return_counts=True))
# Out:
# (array([0, 1, 2], dtype=int32), array([110,  99,  91]))

# %%
for label in range(0, 3):
    draw_fruits(fruits[km.labels_ == label])
    print("\n")

# %%
for label in range(0, 3):
    data = fruits_pca[km.labels_ == label]
    plt.scatter(data[:,0], data[:,1])
plt.legend(['apple', 'banana', 'pineapple'])
plt.show()
